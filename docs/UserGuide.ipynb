# %% [markdown]
# **Upload Files to session storage**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **1. Add Expense**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **New Expense saved in memory**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **3. View Expenses**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **2. Edit Expense**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **6. View budget**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **5. Track Budget**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **7. Save Data**
# ![image.png](data:image/png;base64,...)
